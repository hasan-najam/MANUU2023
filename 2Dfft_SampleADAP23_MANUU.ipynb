# %% [markdown]
# <a href="https://colab.research.google.com/github/hasan-najam/MANUU2023/blob/main/2Dfft_SampleADAP23_MANUU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

image_filename = "clouds.jpeg"

image = plt.imread(image_filename)
plt.imshow(image)

# %%
image = image[:, :, :3].mean(axis=2)  # Convert to grayscale
print(image.shape)

plt.set_cmap("gray")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# (1578, 1600)

# %%
import numpy as np

def calculate_2dft(input):
    ft = np.fft.ifftshift(input)
    ft = np.fft.fft2(ft)
    return np.fft.fftshift(ft)
# Read and process image
image = plt.imread(image_filename)
plt.subplot(131)
plt.imshow(image)
image = image[:, :, :3].mean(axis=2)  # Convert to grayscale
plt.set_cmap("gray")
ft = calculate_2dft(image)
plt.subplot(132)
plt.imshow(image)
plt.axis("off")
plt.subplot(133)
plt.imshow(np.log(abs(ft)))
plt.axis("off")
plt.show()
